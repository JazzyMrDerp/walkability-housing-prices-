# %%
import os
import pandas as pd
from pathlib import Path

# Always resolve paths relative to this notebook's location
PROJECT_ROOT = Path(os.getcwd()).parent  # goes up from /notebooks to project root

zillow_df = pd.read_csv(PROJECT_ROOT / "data" / "zillow.csv")
zillow_df.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     91982         1       77494        zip        TX    TX      Katy
# 1     61148         2        8701        zip        NJ    NJ  Lakewood
# 2     91940         3       77449        zip        TX    TX      Katy
# 3     62080         4       11368        zip        NY    NY  New York
# 4     91733         5       77084        zip        TX    TX   Houston
#
#                                    Metro        CountyName     2000-01-31  \
# 0   Houston-The Woodlands-Sugar Land, TX  Fort Bend County  206742.550589
# 1  New York-Newark-Jersey City, NY-NJ-PA      Ocean County  112457.018826
# 2   Houston-The Woodlands-Sugar Land, TX     Harris County  103923.425615
# 3  New York-Newark-Jersey City, NY-NJ-PA     Queens County  169575.385312
# 4   Houston-The Woodlands-Sugar Land, TX     Harris County  103271.640356
#
#    ...     2025-05-31     2025-06-30     2025-07-31     2025-08-31  \
# 0  ...  488142.171621  485593.460624  483558.159581  482459.221490
# 1  ...  535656.204134  538182.452579  539965.542570  541208.671710
# 2  ...  276457.189524  275455.654292  274513.271507  273576.592187
# 3  ...  518456.396575  520474.846811  523162.354481  524791.771816
# 4  ...  271836.803411  270828.709987  269910.447635  269029.273920
#
#       2025-09-30     2025-10-31     2025-11-30     2025-12-31     2026-01-31  \
# 0  482657.736204  483395.012862  484452.142108  485046.419102  484655.871700
# 1  543758.541550  548645.826577  554560.439690  560798.482252  565263.940118
# 2  272796.563411  272055.592102  271419.013649  271079.442528  270529.284032
# 3  526001.679596  527005.603423  528881.114867  531513.870609  536184.399800
# 4  268146.359244  267290.984611  266557.113653  266211.696542  265704.554898
#
#       2026-02-28
# 0  483255.762764
# 1  568982.895964
# 2  270127.483702
# 3  541021.182326
# 4  265223.632095
#
# [5 rows x 323 columns]

# %% [markdown]
# First lets organize it by zip code

# %%
zillow_zip_sort_df = zillow_df.sort_values(["RegionName"])
zillow_zip_sort_df
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State         City  \
# 7354      58196      7440        1001        zip        MA    MA       Agawam
# 3868      58197      3911        1002        zip        MA    MA      Amherst
# 12635     58200     12819        1005        zip        MA    MA        Barre
# 7624      58201      7715        1007        zip        MA    MA  Belchertown
# 21059     58202     21871        1008        zip        MA    MA    Blandford
# ...         ...       ...         ...        ...       ...   ...          ...
# 18965    100468     19453       99827        zip        AK    AK          NaN
# 14968    100472     15214       99833        zip        AK    AK          NaN
# 10797    100473     10941       99835        zip        AK    AK        Sitka
# 8106     100478      8211       99901        zip        AK    AK    Ketchikan
# 18442    100489     18877       99929        zip        AK    AK     Wrangell
#
#                   Metro                 CountyName     2000-01-31  ...  \
# 7354    Springfield, MA             Hampden County  118073.490835  ...
# 3868    Springfield, MA           Hampshire County  167094.797311  ...
# 12635  Worcester, MA-CT           Worcester County  124659.866254  ...
# 7624    Springfield, MA           Hampshire County  156041.692648  ...
# 21059   Springfield, MA             Hampden County  110728.115478  ...
# ...                 ...                        ...            ...  ...
# 18965               NaN             Haines Borough            NaN  ...
# 14968               NaN         Petersburg Borough            NaN  ...
# 10797               NaN              Sitka Borough            NaN  ...
# 8106      Ketchikan, AK  Ketchikan Gateway Borough            NaN  ...
# 18442               NaN           Wrangell Borough            NaN  ...
#
#           2025-05-31     2025-06-30     2025-07-31     2025-08-31  \
# 7354   322672.040375  322605.320724  322924.603212  323553.755520
# 3868   515709.504202  515053.797371  513546.275732  511192.005318
# 12635  392282.821112  390452.056708  389680.983960  389442.199905
# 7624   450230.268063  449982.549460  449833.339947  449373.493859
# 21059  347975.279653  346278.837735  345669.174273  344883.192600
# ...              ...            ...            ...            ...
# 18965  325219.769370  330680.017181  331989.972370  329878.739004
# 14968  310366.525287  310277.336859  313117.588896  319481.634524
# 10797  488554.383266  499671.295433  503817.310583  501448.066954
# 8106   358684.158588  362683.173460  366682.125367  370816.914660
# 18442  298658.763508  303400.454566  302904.025413  299965.326532
#
#           2025-09-30     2025-10-31     2025-11-30     2025-12-31  \
# 7354   324711.144580  326369.906214  328085.238695  330165.671433
# 3868   509407.266987  508278.174262  508440.932534  509973.277855
# 12635  390139.364757  391265.289820  392590.587188  394696.901398
# 7624   449268.551752  449768.896912  450965.609713  453164.948282
# 21059  345288.512805  346919.989226  348814.285722  350833.467958
# ...              ...            ...            ...            ...
# 18965  325243.208288  321628.635140  321529.752725  322472.908589
# 14968  328457.541067  336609.629604  343777.751162  350324.624727
# 10797  490482.495334  480998.612246  473773.719750  469277.935582
# 8106   374260.158898  377548.697268  379923.765924  381942.466868
# 18442  294582.187603  293376.109472  294721.443869  298250.882018
#
#           2026-01-31     2026-02-28
# 7354   332012.749952  333711.806209
# 3868   512242.128519  514492.174500
# 12635  396196.592007  397515.389028
# 7624   455455.346225  457172.235335
# 21059  352362.766561  353742.309249
# ...              ...            ...
# 18965  323992.401858  325976.288917
# 14968  354828.379755  359212.720415
# 10797  467196.801714  466353.253534
# 8106   383148.390327  383852.776675
# 18442  299687.533208  302261.027721
#
# [26297 rows x 323 columns]

# %%
#Shape of the df
zillow_zip_sort_df.shape
# Out:
# (26297, 323)

# %% [markdown]
# How many NaN are there

# %%
zillow_zip_sort_df.isna().sum()
# Out:
# RegionID      0
# SizeRank      0
# RegionName    0
# RegionType    0
# StateName     0
#              ..
# 2025-10-31    0
# 2025-11-30    1
# 2025-12-31    1
# 2026-01-31    3
# 2026-02-28    3
# Length: 323, dtype: int64

# %% [markdown]
# Separate metadata from the date column

# %%
meta_cols = ['RegionID', 'SizeRank', 'RegionName', 'RegionType',
             'StateName', 'State', 'City', 'Metro', 'CountyName']
print(zillow_df[meta_cols].isna().sum())
# Out:
# RegionID         0
# SizeRank         0
# RegionName       0
# RegionType       0
# StateName        0
# State            0
# City          1040
# Metro         4725
# CountyName       0
# dtype: int64

# %% [markdown]
# Drop rows missing City or Metro

# %%
print(f"Rows before dropping missing City/Metro: {len(zillow_df)}")
zillow_df = zillow_df.dropna(subset=['City', 'Metro'])
print(f"Rows after: {len(zillow_df)}")
# Out:
# Rows before dropping missing City/Metro: 26297
# Rows after: 20851

# %% [markdown]
# Grab columns from only 2021

# %%
cols_2021 = [c for c in zillow_df.columns if c.startswith('2021')]
print(f"2021 columns found: {len(cols_2021)}")  # should be 12 months
print(cols_2021)
# Out:
# 2021 columns found: 12
# ['2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30', '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31', '2021-09-30', '2021-10-31', '2021-11-30', '2021-12-31']

# %%
# ── Keep metadata + 2021 columns only ─────────────────────────────────────────
zillow_2021 = zillow_df[meta_cols + cols_2021].copy()

# ── Drop rows missing City or Metro ───────────────────────────────────────────
zillow_2021 = zillow_2021.dropna(subset=['City', 'Metro'])

# %%
zillow_2021
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State        City  \
# 0         91982         1       77494        zip        TX    TX        Katy
# 1         61148         2        8701        zip        NJ    NJ    Lakewood
# 2         91940         3       77449        zip        TX    TX        Katy
# 3         62080         4       11368        zip        NY    NY    New York
# 4         91733         5       77084        zip        TX    TX     Houston
# ...         ...       ...         ...        ...       ...   ...         ...
# 26291     78282     39992       46799        zip        IN    IN  Zanesville
# 26292     64224     39992       15663        zip        PA    PA     Madison
# 26293     63115     39992       13435        zip        NY    NY    Prospect
# 26295     97497     39992       93962        zip        CA    CA     Salinas
# 26296     78367     39992       46958        zip        IN    IN      Mexico
#
#                                        Metro           CountyName  \
# 0       Houston-The Woodlands-Sugar Land, TX     Fort Bend County
# 1      New York-Newark-Jersey City, NY-NJ-PA         Ocean County
# 2       Houston-The Woodlands-Sugar Land, TX        Harris County
# 3      New York-Newark-Jersey City, NY-NJ-PA        Queens County
# 4       Houston-The Woodlands-Sugar Land, TX        Harris County
# ...                                      ...                  ...
# 26291                           Bluffton, IN         Wells County
# 26292                         Pittsburgh, PA  Westmoreland County
# 26293                         Utica-Rome, NY        Oneida County
# 26295                            Salinas, CA      Monterey County
# 26296                               Peru, IN         Miami County
#
#           2021-01-31  ...     2021-03-31     2021-04-30     2021-05-31  \
# 0      342341.295109  ...  352984.785012  359697.081423  367289.746279
# 1      298872.791651  ...  306295.657939  310870.926542  316556.576573
# 2      208502.125010  ...  213949.731559  217077.990196  220889.048989
# 3      579507.423237  ...  585402.089065  584708.780889  584399.810259
# 4      206918.038452  ...  212761.861553  216068.292615  219915.053766
# ...              ...  ...            ...            ...            ...
# 26291  137059.788627  ...  140384.138192  142143.716172  144230.774469
# 26292            NaN  ...            NaN            NaN            NaN
# 26293  124767.916690  ...  128385.975302  130590.018787  132951.055035
# 26295  662920.597050  ...  680920.444078  692567.269756  705466.233256
# 26296  101989.833963  ...  105657.313563  107300.243505  108833.519279
#
#           2021-06-30     2021-07-31     2021-08-31     2021-09-30  \
# 0      375183.600789  382606.280054  388972.531211  394241.210382
# 1      323180.110161  328930.474915  334031.772734  338632.849840
# 2      225349.729685  229613.709585  233273.389864  236355.014538
# 3      583142.236528  584825.032268  586599.077789  589230.300649
# 4      224212.315565  228066.087917  231070.005526  233271.320019
# ...              ...            ...            ...            ...
# 26291  146562.738522  148880.725996  150674.373230  151634.261831
# 26292            NaN            NaN            NaN            NaN
# 26293  135237.226459  136554.200189  136889.466016  135826.832595
# 26295  718181.638610  727113.882389  732302.461984  735441.707431
# 26296  110451.539554  111874.334452  113102.072743  113771.568322
#
#           2021-10-31     2021-11-30     2021-12-31
# 0      399288.971735  404930.674191  410875.802100
# 1      344188.347524  350341.459606  356470.102240
# 2      239693.544826  243409.008590  247305.320454
# 3      592248.694133  594022.275394  594205.515581
# 4      235717.755730  238720.961787  242247.323813
# ...              ...            ...            ...
# 26291  152051.899212  152542.010849  153324.917422
# 26292            NaN            NaN            NaN
# 26293  134949.904461  134307.045764  133662.591314
# 26295  738925.569134  743693.620392  748360.355190
# 26296  114371.113210  114937.047325  115595.179691
#
# [20851 rows x 21 columns]

# %% [markdown]
# Now we'll use the average home cost in 2021

# %%
zillow_2021['home_value'] = zillow_2021[cols_2021].mean(axis=1).round(2)
zillow_2021 = zillow_2021.dropna(subset=['home_value'])

# %%
zillow_2021
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State        City  \
# 0         91982         1       77494        zip        TX    TX        Katy
# 1         61148         2        8701        zip        NJ    NJ    Lakewood
# 2         91940         3       77449        zip        TX    TX        Katy
# 3         62080         4       11368        zip        NY    NY    New York
# 4         91733         5       77084        zip        TX    TX     Houston
# ...         ...       ...         ...        ...       ...   ...         ...
# 26290     72138     39992       32664        zip        FL    FL    Micanopy
# 26291     78282     39992       46799        zip        IN    IN  Zanesville
# 26293     63115     39992       13435        zip        NY    NY    Prospect
# 26295     97497     39992       93962        zip        CA    CA     Salinas
# 26296     78367     39992       46958        zip        IN    IN      Mexico
#
#                                        Metro        CountyName     2021-01-31  \
# 0       Houston-The Woodlands-Sugar Land, TX  Fort Bend County  342341.295109
# 1      New York-Newark-Jersey City, NY-NJ-PA      Ocean County  298872.791651
# 2       Houston-The Woodlands-Sugar Land, TX     Harris County  208502.125010
# 3      New York-Newark-Jersey City, NY-NJ-PA     Queens County  579507.423237
# 4       Houston-The Woodlands-Sugar Land, TX     Harris County  206918.038452
# ...                                      ...               ...            ...
# 26290                              Ocala, FL     Marion County  220315.746976
# 26291                           Bluffton, IN      Wells County  137059.788627
# 26293                         Utica-Rome, NY     Oneida County  124767.916690
# 26295                            Salinas, CA   Monterey County  662920.597050
# 26296                               Peru, IN      Miami County  101989.833963
#
#        ...     2021-04-30     2021-05-31     2021-06-30     2021-07-31  \
# 0      ...  359697.081423  367289.746279  375183.600789  382606.280054
# 1      ...  310870.926542  316556.576573  323180.110161  328930.474915
# 2      ...  217077.990196  220889.048989  225349.729685  229613.709585
# 3      ...  584708.780889  584399.810259  583142.236528  584825.032268
# 4      ...  216068.292615  219915.053766  224212.315565  228066.087917
# ...    ...            ...            ...            ...            ...
# 26290  ...  228628.949945  233235.230531  239837.110147  246571.518337
# 26291  ...  142143.716172  144230.774469  146562.738522  148880.725996
# 26293  ...  130590.018787  132951.055035  135237.226459  136554.200189
# 26295  ...  692567.269756  705466.233256  718181.638610  727113.882389
# 26296  ...  107300.243505  108833.519279  110451.539554  111874.334452
#
#           2021-08-31     2021-09-30     2021-10-31     2021-11-30  \
# 0      388972.531211  394241.210382  399288.971735  404930.674191
# 1      334031.772734  338632.849840  344188.347524  350341.459606
# 2      233273.389864  236355.014538  239693.544826  243409.008590
# 3      586599.077789  589230.300649  592248.694133  594022.275394
# 4      231070.005526  233271.320019  235717.755730  238720.961787
# ...              ...            ...            ...            ...
# 26290  251904.283961  254968.933945  257895.244499  261109.578338
# 26291  150674.373230  151634.261831  152051.899212  152542.010849
# 26293  136889.466016  135826.832595  134949.904461  134307.045764
# 26295  732302.461984  735441.707431  738925.569134  743693.620392
# 26296  113102.072743  113771.568322  114371.113210  114937.047325
#
#           2021-12-31  home_value
# 0      410875.802100   377138.87
# 1      356470.102240   325932.60
# 2      247305.320454   227211.94
# 3      594205.515581   586782.61
# 4      242247.323813   224885.48
# ...              ...         ...
# 26290  264782.198596   242345.40
# 26291  153324.917422   146518.61
# 26293  133662.591314   132544.04
# 26295  748360.355190   713118.50
# 26296  115595.179691   110144.51
#
# [20202 rows x 22 columns]

# %%
final_cols = meta_cols + ['home_value']
zillow_clean = zillow_2021[final_cols].copy()

# %%
zillow_clean
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State        City  \
# 0         91982         1       77494        zip        TX    TX        Katy
# 1         61148         2        8701        zip        NJ    NJ    Lakewood
# 2         91940         3       77449        zip        TX    TX        Katy
# 3         62080         4       11368        zip        NY    NY    New York
# 4         91733         5       77084        zip        TX    TX     Houston
# ...         ...       ...         ...        ...       ...   ...         ...
# 26290     72138     39992       32664        zip        FL    FL    Micanopy
# 26291     78282     39992       46799        zip        IN    IN  Zanesville
# 26293     63115     39992       13435        zip        NY    NY    Prospect
# 26295     97497     39992       93962        zip        CA    CA     Salinas
# 26296     78367     39992       46958        zip        IN    IN      Mexico
#
#                                        Metro        CountyName  home_value
# 0       Houston-The Woodlands-Sugar Land, TX  Fort Bend County   377138.87
# 1      New York-Newark-Jersey City, NY-NJ-PA      Ocean County   325932.60
# 2       Houston-The Woodlands-Sugar Land, TX     Harris County   227211.94
# 3      New York-Newark-Jersey City, NY-NJ-PA     Queens County   586782.61
# 4       Houston-The Woodlands-Sugar Land, TX     Harris County   224885.48
# ...                                      ...               ...         ...
# 26290                              Ocala, FL     Marion County   242345.40
# 26291                           Bluffton, IN      Wells County   146518.61
# 26293                         Utica-Rome, NY     Oneida County   132544.04
# 26295                            Salinas, CA   Monterey County   713118.50
# 26296                               Peru, IN      Miami County   110144.51
#
# [20202 rows x 10 columns]

# %% [markdown]
# Now sort by RegionName, and make that the ID

# %%
zillow_clean = zillow_clean.sort_values('RegionName')
zillow_clean = zillow_clean.set_index('RegionName')

# %%
zillow_clean = zillow_clean.rename_axis('ZIP')
zillow_clean
# Out:
#        RegionID  SizeRank RegionType StateName State         City  \
# ZIP
# 1001      58196      7440        zip        MA    MA       Agawam
# 1002      58197      3911        zip        MA    MA      Amherst
# 1005      58200     12819        zip        MA    MA        Barre
# 1007      58201      7715        zip        MA    MA  Belchertown
# 1008      58202     21871        zip        MA    MA    Blandford
# ...         ...       ...        ...       ...   ...          ...
# 99712    100387      7208        zip        AK    AK    Fairbanks
# 99714    100388     24015        zip        AK    AK       Salcha
# 99801    100459      4499        zip        AK    AK       Juneau
# 99824    100465     16480        zip        AK    AK       Juneau
# 99901    100478      8211        zip        AK    AK    Ketchikan
#
#                   Metro                    CountyName  home_value
# ZIP
# 1001    Springfield, MA                Hampden County   251806.36
# 1002    Springfield, MA              Hampshire County   391580.68
# 1005   Worcester, MA-CT              Worcester County   293752.74
# 1007    Springfield, MA              Hampshire County   346417.19
# 1008    Springfield, MA                Hampden County   271328.84
# ...                 ...                           ...         ...
# 99712     Fairbanks, AK  Fairbanks North Star Borough   297457.23
# 99714     Fairbanks, AK  Fairbanks North Star Borough   210983.61
# 99801        Juneau, AK                Juneau Borough   402009.03
# 99824        Juneau, AK                Juneau Borough   286847.56
# 99901     Ketchikan, AK     Ketchikan Gateway Borough   331242.30
#
# [20202 rows x 9 columns]

# %%
#Testing location
zillow_clean.loc[11803]
# Out:
# RegionID                                      62273
# SizeRank                                       3815
# RegionType                                      zip
# StateName                                        NY
# State                                            NY
# City                                      Plainview
# Metro         New York-Newark-Jersey City, NY-NJ-PA
# CountyName                            Nassau County
# home_value                                700203.61
# Name: 11803, dtype: object

# %%
import os
import pandas as pd
from pathlib import Path

# Always resolve paths relative to this notebook's location
PROJECT_ROOT = Path(os.getcwd()).parent  # goes up from /notebooks to project root
zillow_clean.to_csv(PROJECT_ROOT / "data" / "zillow_clean.csv")

# %%
test = pd.read_csv(PROJECT_ROOT / "data" / "zillow_clean.csv")
test
# Out:
#          ZIP  RegionID  SizeRank RegionType StateName State         City  \
# 0       1001     58196      7440        zip        MA    MA       Agawam
# 1       1002     58197      3911        zip        MA    MA      Amherst
# 2       1005     58200     12819        zip        MA    MA        Barre
# 3       1007     58201      7715        zip        MA    MA  Belchertown
# 4       1008     58202     21871        zip        MA    MA    Blandford
# ...      ...       ...       ...        ...       ...   ...          ...
# 20197  99712    100387      7208        zip        AK    AK    Fairbanks
# 20198  99714    100388     24015        zip        AK    AK       Salcha
# 20199  99801    100459      4499        zip        AK    AK       Juneau
# 20200  99824    100465     16480        zip        AK    AK       Juneau
# 20201  99901    100478      8211        zip        AK    AK    Ketchikan
#
#                   Metro                    CountyName  home_value
# 0       Springfield, MA                Hampden County   251806.36
# 1       Springfield, MA              Hampshire County   391580.68
# 2      Worcester, MA-CT              Worcester County   293752.74
# 3       Springfield, MA              Hampshire County   346417.19
# 4       Springfield, MA                Hampden County   271328.84
# ...                 ...                           ...         ...
# 20197     Fairbanks, AK  Fairbanks North Star Borough   297457.23
# 20198     Fairbanks, AK  Fairbanks North Star Borough   210983.61
# 20199        Juneau, AK                Juneau Borough   402009.03
# 20200        Juneau, AK                Juneau Borough   286847.56
# 20201     Ketchikan, AK     Ketchikan Gateway Borough   331242.30
#
# [20202 rows x 10 columns]
